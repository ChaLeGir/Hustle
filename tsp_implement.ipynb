# %%
from Basic_functions import tsp_helpers as tsp

# %%
#Great let's change it to what I need
import os
os.chdir(r"C:\Users\cjgir\Documents\Work\Hustle")
os.getcwd()
# Out:
# 'C:\\Users\\cjgir\\Documents\\Work\\Hustle'

# %%
[border, x, y] = tsp.get_border()
stops = tsp.generateStops(200, seed=21, border=border)
[GSol, worked] = tsp.full_tsp(stops, open=True)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'x', 'y', 'xx', 'yy', 'TICTOC'])
# Ax: [2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 1. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 1. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.
#  2. 2. 2. 2. 2. 2. 2. 2.]
# ...

# %%
tsp.printGraph(stops, GSol, x=x, y=y)
